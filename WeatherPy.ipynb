# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
#NUM_POINTS = 25 # DEBUG 1500

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    # else:
    #     print(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %%
# lats = np.random.uniform(lat_range[0], lat_range[1], size=NUM_POINTS)
# lngs = np.random.uniform(lng_range[0], lng_range[1], size=NUM_POINTS)

# lat_lngs = list(zip(lats, lngs))
# print(lat_lngs)

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        #city_weather = # YOUR CODE HERE
      
        response = requests.get(city_url)  
        status_code = response.status_code
        if status_code == 200:
            city_weather = response.json()
            #print(city_weather)
        else:
            city_weather = {}
            #print(status_code, city_url)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        date = datetime.datetime.utcfromtimestamp(city_date).strftime('%Y-%m-%d')
      

        # # Append the City information into city_data list
        city_data.append({"City": city, 
                           "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
    time.sleep(1)           
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | ornskoldsvik
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | timbuktu
# Processing Record 10 of Set 1 | iskateley
# Processing Record 11 of Set 1 | luena
# Processing Record 12 of Set 1 | vorgashor
# Processing Record 13 of Set 1 | hawaiian paradise park
# Processing Record 14 of Set 1 | evanston
# Processing Record 15 of Set 1 | qaqortoq
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | colonia
# Processing Record 18 of Set 1 | tralee
# Processing Record 19 of Set 1 | magadan
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | edinburgh of the seven seas
# Processing Record 22 of Set 1 | margate
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | porto empedocle
# Processing Record 25 of Set 1 | port moresby
# Processing Record 26 of Set 1 | shchigry
# Processing Record 27 of Set 1 | guerrero negro
# Processing Record 28 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | callao
# Processing Record 31 of Set 1 | dalandzadgad
# Processing Record 32 of Set 1 | mount isa
# Processing Record 33 of Set 1 | khromtau
# Processing Record 34 of Set 1 | xintai
# Processing Record 35 of Set 1 | vilyuysk
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | afaahiti
# Processing Record 38 of Set 1 | tazacorte
# Processing Record 39 of Set 1 | anadyr
# Processing Record 40 of Set 1 | katsuren-haebaru
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | papatowai
# Processing Record 43 of Set 1 | codrington
# Processing Record 44 of Set 1 | crane
# Processing Record 45 of Set 1 | quellon
# Processing Record 46 of Set 1 | yel'nya
# Processing Record 47 of Set 1 | olonkinbyen
# Processing Record 48 of Set 1 | port saint john's
# Processing Record 49 of Set 1 | gadzhiyevo
# Processing Record 50 of Set 1 | margaret river
# Processing Record 0 of Set 2 | kibre mengist
# Processing Record 1 of Set 2 | flin flon
# Processing Record 2 of Set 2 | vernon
# Processing Record 3 of Set 2 | eenhana
# Processing Record 4 of Set 2 | tazovsky
# Processing Record 5 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 2 | mikun'
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | ijero-ekiti
# Processing Record 9 of Set 2 | lihue
# Processing Record 10 of Set 2 | muroto-misakicho
# Processing Record 11 of Set 2 | bodo
# Processing Record 12 of Set 2 | och'amch'ire
# Processing Record 13 of Set 2 | argostolion
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | tofol
# Processing Record 16 of Set 2 | college
# Processing Record 17 of Set 2 | pariaman
# Processing Record 18 of Set 2 | nelson bay
# Processing Record 19 of Set 2 | alofi
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | hadibu
# Processing Record 22 of Set 2 | al jawf
# Processing Record 23 of Set 2 | valea stanciului
# Processing Record 24 of Set 2 | blackmans bay
# Processing Record 25 of Set 2 | arba minch
# Processing Record 26 of Set 2 | oranjemund
# Processing Record 27 of Set 2 | dunedin
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | bilibino
# Processing Record 30 of Set 2 | myeik
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | kingston
# Processing Record 33 of Set 2 | choibalsan
# Processing Record 34 of Set 2 | nar'yan-mar
# Processing Record 35 of Set 2 | ust-nera
# Processing Record 36 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 37 of Set 2 | west island
# Processing Record 38 of Set 2 | huaraz
# Processing Record 39 of Set 2 | hamilton
# Processing Record 40 of Set 2 | luwuk
# Processing Record 41 of Set 2 | korla
# Processing Record 42 of Set 2 | chul'man
# Processing Record 43 of Set 2 | pereval's'k
# Processing Record 44 of Set 2 | zhangatas
# Processing Record 45 of Set 2 | machhiwara
# Processing Record 46 of Set 2 | sungai raya
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | paros
# Processing Record 49 of Set 2 | albany
# Processing Record 0 of Set 3 | vorkuta
# Processing Record 1 of Set 3 | wailua homesteads
# Processing Record 2 of Set 3 | weno
# Processing Record 3 of Set 3 | abra pampa
# Processing Record 4 of Set 3 | lupane
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | andergrove
# Processing Record 7 of Set 3 | vilyuchinsk
# Processing Record 8 of Set 3 | whitehorse
# Processing Record 9 of Set 3 | kone
# Processing Record 10 of Set 3 | atafu village
# Processing Record 11 of Set 3 | yacuiba
# Processing Record 12 of Set 3 | charters towers
# Processing Record 13 of Set 3 | ushuaia
# Processing Record 14 of Set 3 | yuzhno-kurilsk
# Processing Record 15 of Set 3 | enewetak
# Processing Record 16 of Set 3 | sao felix do xingu
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | kegeyli shahar
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | san antonio de pale
# Processing Record 22 of Set 3 | kailua-kona
# Processing Record 23 of Set 3 | esfarayen
# Processing Record 24 of Set 3 | lukolela
# Processing Record 25 of Set 3 | rosetta
# Processing Record 26 of Set 3 | levuka
# Processing Record 27 of Set 3 | lyantor
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | ouarzazat
# Processing Record 30 of Set 3 | letlhakeng
# Processing Record 31 of Set 3 | ritchie
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | la quinta
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | old shinyanga
# Processing Record 36 of Set 3 | hami
# Processing Record 37 of Set 3 | chonchi
# Processing Record 38 of Set 3 | tsiombe
# Processing Record 39 of Set 3 | punta arenas
# Processing Record 40 of Set 3 | klaksvik
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | mount gambier
# Processing Record 43 of Set 3 | hammerfest
# Processing Record 44 of Set 3 | rawson
# Processing Record 45 of Set 3 | fale old settlement
# Processing Record 46 of Set 3 | itaituba
# Processing Record 47 of Set 3 | praia da vitoria
# Processing Record 48 of Set 3 | formosa
# Processing Record 49 of Set 3 | pantai cenang
# City not found. Skipping...
# Processing Record 0 of Set 4 | pervari
# Processing Record 1 of Set 4 | minas de marcona
# Processing Record 2 of Set 4 | horta
# Processing Record 3 of Set 4 | sitka
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | pangai
# Processing Record 7 of Set 4 | tevragh zeina
# City not found. Skipping...
# Processing Record 8 of Set 4 | acapulco de juarez
# Processing Record 9 of Set 4 | invercargill
# Processing Record 10 of Set 4 | kyren
# Processing Record 11 of Set 4 | selfoss
# Processing Record 12 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 13 of Set 4 | livermore
# Processing Record 14 of Set 4 | broome
# Processing Record 15 of Set 4 | zhangye
# Processing Record 16 of Set 4 | las varillas
# Processing Record 17 of Set 4 | smithers
# Processing Record 18 of Set 4 | sabha
# Processing Record 19 of Set 4 | fort bragg
# Processing Record 20 of Set 4 | bechar
# Processing Record 21 of Set 4 | sakaiminato
# Processing Record 22 of Set 4 | dhidhdhoo
# Processing Record 23 of Set 4 | tolanaro
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | sinabang
# Processing Record 26 of Set 4 | kilju
# Processing Record 27 of Set 4 | dryden
# Processing Record 28 of Set 4 | colby
# Processing Record 29 of Set 4 | remire-montjoly
# Processing Record 30 of Set 4 | saipan
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | nuuk
# Processing Record 33 of Set 4 | colac
# Processing Record 34 of Set 4 | berriane
# Processing Record 35 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 37 of Set 4 | old town
# Processing Record 38 of Set 4 | tobelo
# Processing Record 39 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 4 | kinik
# Processing Record 41 of Set 4 | prabumulih
# Processing Record 42 of Set 4 | malango
# Processing Record 43 of Set 4 | strelka
# Processing Record 44 of Set 4 | turtas
# Processing Record 45 of Set 4 | goure
# Processing Record 46 of Set 4 | badger
# Processing Record 47 of Set 4 | faya-largeau
# Processing Record 48 of Set 4 | kurchatov
# Processing Record 49 of Set 4 | suozhen
# Processing Record 0 of Set 5 | westport
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | la gi
# Processing Record 3 of Set 5 | dongdu
# Processing Record 4 of Set 5 | baukau
# Processing Record 5 of Set 5 | cassia
# Processing Record 6 of Set 5 | ulladulla
# Processing Record 7 of Set 5 | urengoy
# Processing Record 8 of Set 5 | nykarleby
# Processing Record 9 of Set 5 | mmabatho
# Processing Record 10 of Set 5 | taro
# Processing Record 11 of Set 5 | taulaga
# Processing Record 12 of Set 5 | mubende
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | port augusta
# Processing Record 15 of Set 5 | stanley
# Processing Record 16 of Set 5 | dudinka
# Processing Record 17 of Set 5 | otofuke
# Processing Record 18 of Set 5 | labrador city
# Processing Record 19 of Set 5 | keflavik
# Processing Record 20 of Set 5 | vilhena
# Processing Record 21 of Set 5 | gordonvale
# Processing Record 22 of Set 5 | saint-joseph
# Processing Record 23 of Set 5 | port mathurin
# Processing Record 24 of Set 5 | mwatate
# Processing Record 25 of Set 5 | sao vicente
# Processing Record 26 of Set 5 | kokuy
# Processing Record 27 of Set 5 | isafjordur
# Processing Record 28 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 29 of Set 5 | kokopo
# Processing Record 30 of Set 5 | haenam
# Processing Record 31 of Set 5 | tanout
# Processing Record 32 of Set 5 | daru
# Processing Record 33 of Set 5 | brechin
# Processing Record 34 of Set 5 | aasiaat
# Processing Record 35 of Set 5 | udachny
# Processing Record 36 of Set 5 | st. john's
# Processing Record 37 of Set 5 | mahibadhoo
# Processing Record 38 of Set 5 | rikaze
# Processing Record 39 of Set 5 | villa gesell
# Processing Record 40 of Set 5 | kashgar
# Processing Record 41 of Set 5 | malakal
# Processing Record 42 of Set 5 | mirnyy
# Processing Record 43 of Set 5 | seminole
# Processing Record 44 of Set 5 | chinacota
# Processing Record 45 of Set 5 | celestun
# Processing Record 46 of Set 5 | sarupathar
# Processing Record 47 of Set 5 | lisala
# Processing Record 48 of Set 5 | rio grande
# Processing Record 49 of Set 5 | praya
# Processing Record 0 of Set 6 | pinotepa nacional
# Processing Record 1 of Set 6 | beyneu
# Processing Record 2 of Set 6 | ulsteinvik
# Processing Record 3 of Set 6 | bridgewater
# Processing Record 4 of Set 6 | arraial do cabo
# Processing Record 5 of Set 6 | lasem
# Processing Record 6 of Set 6 | santiago papasquiaro
# City not found. Skipping...
# Processing Record 7 of Set 6 | okha
# Processing Record 8 of Set 6 | la passe
# Processing Record 9 of Set 6 | upata
# Processing Record 10 of Set 6 | pisco
# Processing Record 11 of Set 6 | polyarnyy
# Processing Record 12 of Set 6 | zaozersk
# Processing Record 13 of Set 6 | sinop
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | wamba
# Processing Record 16 of Set 6 | gamay
# Processing Record 17 of Set 6 | haiku-pauwela
# Processing Record 18 of Set 6 | indi
# Processing Record 19 of Set 6 | villa ojo de agua
# Processing Record 20 of Set 6 | portland
# Processing Record 21 of Set 6 | broken hill
# Processing Record 22 of Set 6 | saint-pierre
# Processing Record 23 of Set 6 | arafat
# Processing Record 24 of Set 6 | juneau
# Processing Record 25 of Set 6 | egilsstadir
# Processing Record 26 of Set 6 | nova sintra
# Processing Record 27 of Set 6 | mankoeng
# Processing Record 28 of Set 6 | la sarre
# Processing Record 29 of Set 6 | coquimbo
# Processing Record 30 of Set 6 | noosa heads
# Processing Record 31 of Set 6 | harstad
# Processing Record 32 of Set 6 | tsaratanana
# Processing Record 33 of Set 6 | sabt alalayah
# City not found. Skipping...
# Processing Record 34 of Set 6 | kem'
# Processing Record 35 of Set 6 | kirillov
# Processing Record 36 of Set 6 | shahr-e babak
# Processing Record 37 of Set 6 | mananara
# Processing Record 38 of Set 6 | city of balikpapan
# Processing Record 39 of Set 6 | utrik
# Processing Record 40 of Set 6 | brisas de zicatela
# Processing Record 41 of Set 6 | malvan
# Processing Record 42 of Set 6 | zhob
# Processing Record 43 of Set 6 | severo-yeniseyskiy
# Processing Record 44 of Set 6 | thames
# Processing Record 45 of Set 6 | tanjung pandan
# Processing Record 46 of Set 6 | palmer
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | harper
# Processing Record 49 of Set 6 | talavera
# Processing Record 0 of Set 7 | weyburn
# Processing Record 1 of Set 7 | dolinsk
# Processing Record 2 of Set 7 | beau vallon
# Processing Record 3 of Set 7 | kourou
# Processing Record 4 of Set 7 | jakobstad
# Processing Record 5 of Set 7 | santa marta
# Processing Record 6 of Set 7 | bitkine
# Processing Record 7 of Set 7 | igarka
# Processing Record 8 of Set 7 | turek
# Processing Record 9 of Set 7 | aripuana
# Processing Record 10 of Set 7 | rio san juan
# Processing Record 11 of Set 7 | mahalapye
# Processing Record 12 of Set 7 | galliano
# Processing Record 13 of Set 7 | al kharijah
# Processing Record 14 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 15 of Set 7 | bamboo flat
# Processing Record 16 of Set 7 | touros
# Processing Record 17 of Set 7 | reggane
# Processing Record 18 of Set 7 | kismayo
# Processing Record 19 of Set 7 | mazamari
# Processing Record 20 of Set 7 | ngurore
# Processing Record 21 of Set 7 | kolonia
# Processing Record 22 of Set 7 | tabou
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | ratnapura
# Processing Record 25 of Set 7 | doctor alberto oviedo mota
# Processing Record 26 of Set 7 | kingscliff
# Processing Record 27 of Set 7 | cururupu
# Processing Record 28 of Set 7 | mirny
# Processing Record 29 of Set 7 | uliastay
# Processing Record 30 of Set 7 | qarqaraly
# Processing Record 31 of Set 7 | koulikoro
# Processing Record 32 of Set 7 | bam
# Processing Record 33 of Set 7 | susuman
# Processing Record 34 of Set 7 | wainwright
# Processing Record 35 of Set 7 | acarau
# Processing Record 36 of Set 7 | selibaby
# Processing Record 37 of Set 7 | mandalgovi
# Processing Record 38 of Set 7 | puerto aysen
# Processing Record 39 of Set 7 | dhamar
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | uturoa
# Processing Record 42 of Set 7 | niquelandia
# Processing Record 43 of Set 7 | ajaokuta
# Processing Record 44 of Set 7 | bredasdorp
# Processing Record 45 of Set 7 | holmsund
# Processing Record 46 of Set 7 | palapye
# Processing Record 47 of Set 7 | donetsk
# Processing Record 48 of Set 7 | armacao de buzios
# Processing Record 49 of Set 7 | gao
# Processing Record 0 of Set 8 | turkmenbasy
# Processing Record 1 of Set 8 | boa esperanca
# Processing Record 2 of Set 8 | impfondo
# Processing Record 3 of Set 8 | barra de santo antonio
# Processing Record 4 of Set 8 | masuguru
# Processing Record 5 of Set 8 | horodyshche
# Processing Record 6 of Set 8 | klyuchi
# Processing Record 7 of Set 8 | lichinga
# Processing Record 8 of Set 8 | kuanda
# Processing Record 9 of Set 8 | karratha
# Processing Record 10 of Set 8 | dwarka
# Processing Record 11 of Set 8 | puerto maldonado
# Processing Record 12 of Set 8 | pacific grove
# Processing Record 13 of Set 8 | bahir dar
# Processing Record 14 of Set 8 | kaiapoi
# Processing Record 15 of Set 8 | beipiao
# Processing Record 16 of Set 8 | port hedland
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 19 of Set 8 | ponta delgada
# Processing Record 20 of Set 8 | fortaleza
# Processing Record 21 of Set 8 | balykchy
# Processing Record 22 of Set 8 | soledade
# Processing Record 23 of Set 8 | porto novo
# Processing Record 24 of Set 8 | plastun
# Processing Record 25 of Set 8 | iwaki
# Processing Record 26 of Set 8 | las tablas
# Processing Record 27 of Set 8 | banda aceh
# Processing Record 28 of Set 8 | osterholz-scharmbeck
# Processing Record 29 of Set 8 | ambagarh chauki
# Processing Record 30 of Set 8 | ilhabela
# Processing Record 31 of Set 8 | queenstown
# Processing Record 32 of Set 8 | kodok
# City not found. Skipping...
# Processing Record 33 of Set 8 | bansang
# Processing Record 34 of Set 8 | happy valley-goose bay
# Processing Record 35 of Set 8 | bodden town
# Processing Record 36 of Set 8 | casa santa
# City not found. Skipping...
# Processing Record 37 of Set 8 | lincoln city
# Processing Record 38 of Set 8 | freetown
# Processing Record 39 of Set 8 | fenyi
# Processing Record 40 of Set 8 | mocimboa
# Processing Record 41 of Set 8 | al mijlad
# Processing Record 42 of Set 8 | waingapu
# Processing Record 43 of Set 8 | santiago de cao
# Processing Record 44 of Set 8 | general salgado
# Processing Record 45 of Set 8 | jieshi
# Processing Record 46 of Set 8 | ciudad melchor muzquiz
# Processing Record 47 of Set 8 | kittila
# Processing Record 48 of Set 8 | kapuskasing
# Processing Record 49 of Set 8 | yorosso
# Processing Record 0 of Set 9 | belmonte
# Processing Record 1 of Set 9 | hotarele
# Processing Record 2 of Set 9 | ivanava
# Processing Record 3 of Set 9 | kenora
# Processing Record 4 of Set 9 | castillos
# Processing Record 5 of Set 9 | la ronge
# Processing Record 6 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 7 of Set 9 | sur
# Processing Record 8 of Set 9 | isle of lewis
# City not found. Skipping...
# Processing Record 9 of Set 9 | villamontes
# Processing Record 10 of Set 9 | carnarvon
# Processing Record 11 of Set 9 | vadso
# Processing Record 12 of Set 9 | fraserburgh
# Processing Record 13 of Set 9 | cabo san lucas
# Processing Record 14 of Set 9 | mil'kovo
# Processing Record 15 of Set 9 | sorong
# Processing Record 16 of Set 9 | tecumseh
# Processing Record 17 of Set 9 | punta cardon
# Processing Record 18 of Set 9 | mali
# Processing Record 19 of Set 9 | pemangkat
# Processing Record 20 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 21 of Set 9 | eaglehawk
# Processing Record 22 of Set 9 | coahuayana de hidalgo
# Processing Record 23 of Set 9 | ellsworth
# Processing Record 24 of Set 9 | berdigestyakh
# Processing Record 25 of Set 9 | quinte west
# Processing Record 26 of Set 9 | adigrat
# Processing Record 27 of Set 9 | nemuro
# Processing Record 28 of Set 9 | taroa
# Processing Record 29 of Set 9 | vicuna
# Processing Record 30 of Set 9 | mawu
# Processing Record 31 of Set 9 | rumbek
# Processing Record 32 of Set 9 | calp
# Processing Record 33 of Set 9 | karoi
# Processing Record 34 of Set 9 | mariehamn
# Processing Record 35 of Set 9 | simga
# Processing Record 36 of Set 9 | gallivare
# City not found. Skipping...
# Processing Record 37 of Set 9 | zaragoza
# Processing Record 38 of Set 9 | kimbe
# Processing Record 39 of Set 9 | lata
# Processing Record 40 of Set 9 | hastings
# Processing Record 41 of Set 9 | bolobo
# Processing Record 42 of Set 9 | axim
# Processing Record 43 of Set 9 | ferkessedougou
# Processing Record 44 of Set 9 | beloyarskiy
# Processing Record 45 of Set 9 | jinshi
# Processing Record 46 of Set 9 | bada
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | laguna
# Processing Record 49 of Set 9 | bannalec
# Processing Record 0 of Set 10 | flying fish cove
# Processing Record 1 of Set 10 | howrah
# Processing Record 2 of Set 10 | badr hunayn
# Processing Record 3 of Set 10 | tshabong
# Processing Record 4 of Set 10 | gaigeturi
# Processing Record 5 of Set 10 | pawni
# Processing Record 6 of Set 10 | cidreira
# Processing Record 7 of Set 10 | lerwick
# Processing Record 8 of Set 10 | la'ie
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | puerto baquerizo moreno
# Processing Record 11 of Set 10 | tuburan
# Processing Record 12 of Set 10 | thanh hoa
# Processing Record 13 of Set 10 | tura
# Processing Record 14 of Set 10 | nehoiu
# Processing Record 15 of Set 10 | steinheim am albuch
# Processing Record 16 of Set 10 | aral
# Processing Record 17 of Set 10 | santa eularia des riu
# Processing Record 18 of Set 10 | usinsk
# Processing Record 19 of Set 10 | assare
# Processing Record 20 of Set 10 | zakynthos
# Processing Record 21 of Set 10 | chilliwack
# Processing Record 22 of Set 10 | kudahuvadhoo
# Processing Record 23 of Set 10 | la manga del mar menor
# Processing Record 24 of Set 10 | yamba
# Processing Record 25 of Set 10 | mogoytuy
# Processing Record 26 of Set 10 | safi
# Processing Record 27 of Set 10 | constantia
# Processing Record 28 of Set 10 | alterosa
# Processing Record 29 of Set 10 | bafia
# Processing Record 30 of Set 10 | nakambala
# Processing Record 31 of Set 10 | kaitong
# Processing Record 32 of Set 10 | wankyi
# Processing Record 33 of Set 10 | jinka
# Processing Record 34 of Set 10 | puerto cabezas
# Processing Record 35 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 36 of Set 10 | khandyga
# Processing Record 37 of Set 10 | pagar alam
# Processing Record 38 of Set 10 | ataq
# Processing Record 39 of Set 10 | agogo
# Processing Record 40 of Set 10 | parabel'
# Processing Record 41 of Set 10 | port isabel
# Processing Record 42 of Set 10 | padang
# Processing Record 43 of Set 10 | sungailiat
# Processing Record 44 of Set 10 | ta`u
# Processing Record 45 of Set 10 | esmeralda
# Processing Record 46 of Set 10 | maintirano
# Processing Record 47 of Set 10 | dem'yanovo
# Processing Record 48 of Set 10 | gueltat zemmour
# City not found. Skipping...
# Processing Record 49 of Set 10 | lamu
# Processing Record 0 of Set 11 | san sebastian de la gomera
# Processing Record 1 of Set 11 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 2 of Set 11 | fuyu
# Processing Record 3 of Set 11 | hirara
# Processing Record 4 of Set 11 | dunay
# Processing Record 5 of Set 11 | basco
# Processing Record 6 of Set 11 | grand blanc
# Processing Record 7 of Set 11 | jean-rabel
# Processing Record 8 of Set 11 | rabaul
# Processing Record 9 of Set 11 | canico
# Processing Record 10 of Set 11 | nagqu
# Processing Record 11 of Set 11 | langtoucun
# Processing Record 12 of Set 11 | sirte
# Processing Record 13 of Set 11 | quezon
# Processing Record 14 of Set 11 | gizo
# Processing Record 15 of Set 11 | kristiansund
# Processing Record 16 of Set 11 | beira
# Processing Record 17 of Set 11 | turuntayevo
# Processing Record 18 of Set 11 | newman
# Processing Record 19 of Set 11 | jerada
# Processing Record 20 of Set 11 | novyy urgal
# Processing Record 21 of Set 11 | safaga
# Processing Record 22 of Set 11 | hengchun
# Processing Record 23 of Set 11 | mukah
# City not found. Skipping...
# Processing Record 24 of Set 11 | mugia
# Processing Record 25 of Set 11 | isabela
# Processing Record 26 of Set 11 | urucui
# Processing Record 27 of Set 11 | midvagur
# Processing Record 28 of Set 11 | santa ines
# Processing Record 29 of Set 11 | seosan
# Processing Record 30 of Set 11 | prince rupert
# Processing Record 31 of Set 11 | santa terezinha
# Processing Record 32 of Set 11 | yurgamysh
# Processing Record 33 of Set 11 | papao
# Processing Record 34 of Set 11 | severnoye
# Processing Record 35 of Set 11 | kujama
# Processing Record 36 of Set 11 | nadym
# Processing Record 37 of Set 11 | muisne
# Processing Record 38 of Set 11 | chorfa
# Processing Record 39 of Set 11 | gushu
# Processing Record 40 of Set 11 | nueve de julio
# Processing Record 41 of Set 11 | okhotsk
# Processing Record 42 of Set 11 | kavaratti
# Processing Record 43 of Set 11 | korhogo
# Processing Record 44 of Set 11 | fort mcmurray
# Processing Record 45 of Set 11 | recani
# Processing Record 46 of Set 11 | ladario
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | kyzylorda
# Processing Record 49 of Set 11 | shimokizukuri
# Processing Record 0 of Set 12 | korotchaevo
# City not found. Skipping...
# Processing Record 1 of Set 12 | timimoun
# Processing Record 2 of Set 12 | leer
# Processing Record 3 of Set 12 | kandla
# Processing Record 4 of Set 12 | sant'ambrogio di valpollicella
# Processing Record 5 of Set 12 | chatillon-sur-seine
# Processing Record 6 of Set 12 | puerto deseado
# Processing Record 7 of Set 12 | talcahuano
# Processing Record 8 of Set 12 | whakatane
# Processing Record 9 of Set 12 | kamaishi
# Processing Record 10 of Set 12 | borogontsy
# Processing Record 11 of Set 12 | huarmey
# Processing Record 12 of Set 12 | ternate
# Processing Record 13 of Set 12 | kotlas
# Processing Record 14 of Set 12 | tucurui
# Processing Record 15 of Set 12 | cole harbour
# Processing Record 16 of Set 12 | mata-utu
# Processing Record 17 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 18 of Set 12 | postmasburg
# City not found. Skipping...
# Processing Record 19 of Set 12 | kirensk
# Processing Record 20 of Set 12 | kerikeri
# Processing Record 21 of Set 12 | arteche
# Processing Record 22 of Set 12 | rio preto da eva
# Processing Record 23 of Set 12 | changji
# Processing Record 24 of Set 12 | katpur
# Processing Record 25 of Set 12 | kuruman
# Processing Record 26 of Set 12 | santa elena de uairen
# Processing Record 27 of Set 12 | eydhafushi
# Processing Record 28 of Set 12 | oregon
# Processing Record 29 of Set 12 | camalu
# Processing Record 30 of Set 12 | minas
# Processing Record 31 of Set 12 | helena valley west central
# Processing Record 32 of Set 12 | conception bay south
# Processing Record 33 of Set 12 | rongelap
# Processing Record 34 of Set 12 | mossel bay
# Processing Record 35 of Set 12 | sola
# Processing Record 36 of Set 12 | natal
# Processing Record 37 of Set 12 | raduzhnyy
# Processing Record 38 of Set 12 | mao
# Processing Record 39 of Set 12 | santo tome
# Processing Record 40 of Set 12 | san antonio
# Processing Record 41 of Set 12 | pacasmayo

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(7,5))
plt.scatter(city_data_df.Lat,city_data_df["Max Temp"], edgecolor="black", s=50)

# Incorporate the other graph properties
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Max Temperature (C)", fontsize=12, fontstyle="italic")
plt.title(f"City Max Latitude vs. Temperature ({date})", fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", alpha=1)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(7, 5))
plt.scatter(city_data_df.Lat,city_data_df.Humidity, edgecolor="black", s=50)

# Incorporate the other graph properties
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Humidity (%)", fontsize=12, fontstyle="italic")
plt.title(f"City Latitude vs. Humidity ({date})", fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", alpha=1)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(7, 5))
plt.scatter(city_data_df.Lat,city_data_df.Cloudiness, edgecolor="black", s=50)

# Incorporate the other graph properties
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Cloudiness (%)", fontsize=12, fontstyle="italic")
plt.title(f"City Latitude vs. Cloudiness ({date})", fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", alpha=1)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(7, 5))
plt.scatter(city_data_df.Lat,city_data_df["Wind Speed"], edgecolor="black", s=50)

# Incorporate the other graph properties
plt.xlabel("Latitude", fontsize=12, fontstyle="italic")
plt.ylabel("Wind Speed (m/s)", fontsize=12, fontstyle="italic")
plt.title(f"City Latitude vs. Wind Speed ({date})", fontweight="bold", fontsize=16)
plt.grid(color="lightgrey", alpha=1)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def reg_fun(x_val, y_val, y_label, a_pos):
    (slope, intercept,rvalue, pvalue, stderr)= linregress(x_val,y_val)
    regress_values=x_val * slope + intercept
    line_eq= f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    
    plt.scatter(x_val,y_val)
    plt.plot(x_val, regress_values, color='red')
    plt.annotate(line_eq, a_pos, fontsize=14, color='red')
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.title(f"Latitude vs {y_label}")
    print(f"The r-squared-value is: {round(rvalue**2, 5)}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df.Lat >=0]
# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df.Lat <0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val=northern_hemi_df.Lat
y_val=northern_hemi_df["Max Temp"]
reg_fun(x_val, y_val, "Temperature",(0,0))

# %%
# Linear regression on Southern Hemisphere
x_val=southern_hemi_df.Lat
y_val=southern_hemi_df["Max Temp"]
reg_fun(x_val, y_val, "Temperature", (-30,0))

# %% [markdown]
# **Discussion about the linear relationship:
# With temperaure northen hemisphere and southern hemisphere have moderate negative and positive relationship respectively

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val=northern_hemi_df.Lat
y_val=northern_hemi_df.Humidity
reg_fun(x_val, y_val, "Humidity",(0, 20))

# %%
# Southern Hemisphere
x_val=southern_hemi_df.Lat
y_val=southern_hemi_df.Humidity
reg_fun(x_val, y_val, "Humidity", (-50,30))

# %% [markdown]
# **Discussion about the linear relationship:**
# With humidity northen hemisphere and southern hemisphere have very weak negative and positive relationship respectively

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val=northern_hemi_df.Lat
y_val=northern_hemi_df.Cloudiness
reg_fun(x_val, y_val, "Cloudiness",(0,0))

# %%
# Southern Hemisphere
x_val=southern_hemi_df.Lat
y_val=southern_hemi_df.Cloudiness
reg_fun(x_val, y_val, "Cloudiness",(-55,0))

# %% [markdown]
# **Discussion about the linear relationship:** cloudiness have very weak relationship with northen and southern hemishpere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val=northern_hemi_df.Lat
y_val=northern_hemi_df["Wind Speed"]
reg_fun(x_val, y_val, "Wind Speed",(0,0))

# %%
# Southern Hemisphere
x_val=southern_hemi_df.Lat
y_val=southern_hemi_df["Wind Speed"]
reg_fun(x_val, y_val, "Wind Speed",(-50, 15))

# %% [markdown]
# **Discussion about the linear relationship:** wind speed have very weak relation in northen and southern relationship
